# %% [markdown]
# <a href="https://colab.research.google.com/github/divyadn-analytics/SQL-Practice/blob/main/google_colab_practice_07102026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hello World in Python
#
# This is a simple program that prints the text 'Hello, Colab!' to the console. It's often the first program people learn when starting a new programming language.

# %%
print('Hello, Colab!')
# Out:
# Hello, Colab!

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
x=3
y=4
print(x+y)
# Out:
# 7

# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %%
a=b=10
print(a,b)
# Out:
# 10 10

# %%
x,y,z=1,2.5,"world"
print(x,y,z)
# Out:
# 1 2.5 world

# %%
x=1
y=x
y=y+1
print(x)
print(y)
# Out:
# 1
# 2

# %%
x=1
y=3
z=2
# del x  # Removed the 'del x' line
print(x+y+z)
# Out:
# 6

# %%
a,b=5,2
a,b=b,a
print(a,b)
# Out:
# 2 5

# %%
word="class"
length=len(word)
print("length of the word:",length)
# Out:
# length of the word: 5

# %%
word="sunday"
length=len(word)
print("length of the word:",length)
# Out:
# length of the word: 6

# %%
word="Python"
length=len(word)
print("length of the word:",length)
# Out:
# length of the word: 6

# %%
a=3
b=5.5
c=2+5j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
def greet():
  msg="hello!have a wonderful sunday"
  print(msg)
greet()
# Out:
# hello!have a wonderful sunday

# %%
msg="class is good"
msg1="yes thats true"
display()
print("inside function:",msg)
display()
print("outside function:",msg1)
# Out:
# inside function: class is good
# outside function: yes thats true

# %%
msg="class is good"
msg1="yes thats true"
def display():
    print("inside function:",msg)
display()
def display2():
    print("outside function:",msg1)
display2()
# Out:
# inside function: class is good
# outside function: yes thats true

# %%
def greet(name):
    print("hello",name)
greet("class")
greet("all")
greet("trainer")
# Out:
# hello class
# hello all
# hello trainer

# %%
print(2)
# Out:
# 2
