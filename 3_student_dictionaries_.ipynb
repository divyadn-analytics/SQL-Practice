# %% [markdown]
# <a href="https://colab.research.google.com/github/divyadn-analytics/SQL-Practice/blob/main/3_student_dictionaries_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student1={"first_name":"Max","last_name":"smith","roll_number":101,"course":"science"}
stuent2={"first_name":"andy","last_name":"rush","roll_number":201,"course":"Robetics"}
student3={"first_name":"Nancy","last_name":"gram","roll_number":301,"course":"analytics"}
students=[student1,stuent2,student3]
for s in students:
    print(s["last_name"])
# Out:
# smith
# rush
# gram

# %%
student1={"first_name":"Max","last_name":"smith","roll_number":101,"course":"science"}
stuent2={"first_name":"andy","last_name":"rush","roll_number":201,"course":"Robetics"}
student3={"first_name":"Nancy","last_name":"gram","roll_number":301,"course":"analytics"}
students=[student1,stuent2,student3]
for s in students:
    s.pop("last_name")
    print(s)
# Out:
# {'first_name': 'Max', 'roll_number': 101, 'course': 'science'}
# {'first_name': 'andy', 'roll_number': 201, 'course': 'Robetics'}
# {'first_name': 'Nancy', 'roll_number': 301, 'course': 'analytics'}

# %%
student1={"first_name":"Max","last_name":"smith","roll_number":101,"course":"science"}
stuent2={"first_name":"andy","last_name":"rush","roll_number":201,"course":"Robetics"}
student3={"first_name":"Nancy","last_name":"gram","roll_number":301,"course":"analytics"}
students=[student1,stuent2,student3]
for s in students:
   s.pop("last_name")
   print(s)
# Out:
# {'first_name': 'Max', 'roll_number': 101, 'course': 'science'}
# {'first_name': 'andy', 'roll_number': 201, 'course': 'Robetics'}
# {'first_name': 'Nancy', 'roll_number': 301, 'course': 'analytics'}
