# %% [markdown]
# <a href="https://colab.research.google.com/github/divyadn-analytics/SQL-Practice/blob/main/20_practice_ques_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. number is positive, negetive or zero
x=10
if x > 0:
    print("x > 0: positive")
elif x < 0:
    print ("x < 0:Negetive")
else:
    print ("x == 0 :zero")
# Out:
# x > 0: positive

# %%
# 2. number even or odd
num = int(input ("enter the number:"))
if num % 2 == 0:
    print("the num is even")
else:
    print("the num is odd")
# Out:
# enter the number:4
# the num is even

# %%
# 3.largest of 2 numbers
num1=int(input("enter the first number:"))
num2=int(input("enter the second number:"))
if num1 > num2:
    print("num1 is greater")
elif num2 > num1:
    print("num2 is greater")
else:
    print("both numbers are equal")
# Out:
# enter the first number:5
# enter the second number:8
# num2 is greater

# %%
# 5.a character is a Vowel or Consonant
ch = input("Enter a character: ")
if(ch=='A' or ch=='a' or ch=='E' or ch =='e' or ch=='I'
 or ch=='i' or ch=='o' or ch=='O' or ch=='U' or ch=='u'):
    print(ch, "is a Vowel")
else:
    print(ch, "is a Consonant")
# Out:
# Enter a character: a
# a is a Vowel

# %%
# 5.a character is a Vowel or Consonant
ch = input("Enter a character: ").lower()
if ch in "aeiou":
    print(ch,"is a vowel")
else:
    print(ch,"is a consonant")
# Out:
# Enter a character: class
# class is a consonant

# %%
# 6.the largest of three numbers
num1=int(input("enter the first number:"))
num2=int(input("enter the second number:"))
num3=int(input("enter the third number:"))
if num1 > num2 and num1 > num3:
    print("num1 is greater")
elif num2 > num1 and num2 > num3:
    print("num2 is greater")
else:
    print("num3 is greater")
# Out:
# enter the first number:20
# enter the second number:40
# enter the third number:60
# num3 is greater

# %%
# 6.the largest of three numbers
if num1 > num2:
    if num1 > num3:
        print("num1 is greater")
    else:
        print("num3 is greater")
elif num2 > num1:
    if num2 > num3:
        print("num2 is greater")
    else:
        print("num3 is greater")
# Out:
# num3 is greater

# %%
# 7.Check whether a number is divisible by both 3 and 5.
num=int(input("enter the number:"))
num1=int(input("enter the number:"))
if num % 3 == 0 and num % 5 == 0:
    print("the number is divisible by both 3 and 5")
    print(num)
else:
    print("the number is not divisible by both 3 and 5")
    print(num1)
# Out:
# enter the number:15
# enter the number:7
# the number is divisible by both 3 and 5
# 15

# %%
# Determine whether a triangle is Equilateral, Isosceles, or Scalene based on its three sides.
side1=int(input("enter the first side:"))
side2=int(input("enter the second side:"))
side3=int(input("enter the third side:"))
if side1 == side2 == side3:
    print("the triangle is equilateral")
elif side1 == side2 or side1 == side3 or side2 == side3:
    print("the triangle is isosceles")
else:
    print("the triangle is scalene")
# Out:
# enter the first side:10
# enter the second side:8
# enter the third side:6
# the triangle is scalene

# %%
# 9.	Calculate an electricity bill category based on units consumed.
units=int(input("enter the number of units consumed:"))
if units <= 100:
    print("low usage")
elif units <= 200:
    print("medium usage")
elif units <= 300:
    print("high usage")
else:
    print("very high usage")
# Out:
# enter the number of units consumed:500
# very high usage

# %%
# 10.	Create a simple calculator using if-elif-else (+, -, *, /).
num1=int(input("enter the first number:"))
num2=int(input("enter the second number:"))
operator=input("enter the operator:")
if operator == "+":
    print(num1+num2)
elif operator == "-":
    print(num1-num2)
elif operator == "*":
    print(num1*num2)
elif operator == "/":
    print(num1/num2)
    print(num2/num1)
else:
    print("invalid operator")
# Out:
# enter the first number:2
# enter the second number:4
# enter the operator:*
# 8

# %%
#1.Suppose a person has age 26 , person is eligible to vote or not. The minimum age for voting is 18 years.
age=int(input("enter the age:"))
if age >= 18:
    print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# enter the age:26
# eligible to vote

# %%
#2.student exam passing marks criteria
marks=int(input("enter the marks:"))
if marks >= 90:
    print("excellant")
elif marks >= 80:
    print("good")
elif marks >= 70:
    print("fair")
else:
    print("fail")
# Out:
# enter the marks:85
# good
