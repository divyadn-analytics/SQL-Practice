# %% [markdown]
# <a href="https://colab.research.google.com/github/divyadn-analytics/SQL-Practice/blob/main/shopping_cart_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# shopping cart learnings
name= input("enter your name:")
print (name)
# Out:
# enter your name:divya
# divya

# %%
products={"apple","banana","milk"}
choice = input("enter the product:").lower()
if choice in products:
  print("products avaiable")
else:
  print("product not available")
# Out:
# enter the product:apple
# products avaiable

# %%
products= {"apple",30,"banana",10,"milk",20,"yogurt",15}
choice=input("enter the product:").lower()
if choice in products:
    print("product is available")
    print("price:",products[choice])
else:
    print("sorry!product is not available")
# Out:
# enter the product:oats
# sorry!product is not available

# %%
product={"apple":30,"banana":10,"milk":20,"yogurt":15}
choice=input("enter the product:").lower()
quantity=int(input("enter the quantity:"))
if choice in products:
    print("product is available")
    print("price:",product[choice])
else:print("sorry!product not available")
# Out:
# enter the product:apple
# enter the quantity:2
# product is available
# price: 30

# %%
product={"apple":30,"banana":10,"milk":20,"yogurt":15} #dictionary
choice=input("enter the product:").lower() # question how do we write or add any to accept all case senitive?
quantity=int(input("enter the quantity:"))
if choice in product:
    print("product is available")
    print("price:",product[choice])
    total=product[choice]*quantity
    print("total:",total)
else:
    print("sorry!product is not available")
# Out:
# enter the product:oats
# enter the quantity:1
# sorry!product is not available

# %%
#while True: "Create a loop that will keep running because the condition is always True." It is like telling Python:
#The loop continues until the customer chooses to exit. I used break to stop the loop when the customer does not want to continue shopping."

# %%
count=1
while count<= 5:
  print(count)
  count = count+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
while True:
    print("shopping")
    break
# Out:
# shopping

# %%
product={"apple":30,"banana":10,"milk":20,"yogurt":15}
while True:
    choice=input("enter the product:").lower()
    quantity=int(input("enter the quantity:"))
    if choice in product:
        print("product is available")
        print("price:",product[choice])
        total=product[choice]*quantity
        print("total:",total)
    else:
        print("sorry!product is not available")
    again=input("do you want to continue shooping?").lower()
    if again=='no':
       break
# Out:
# enter the product:apple
# enter the quantity:2
# product is available
# price: 30
# total: 60
# do you want to continue shooping?yes
# enter the product:banana
# enter the quantity:5
# product is available
# price: 10
# total: 50
# do you want to continue shooping?yes
# enter the product:yogurt
# enter the quantity:4
# product is available
# price: 15
# total: 60
# do you want to continue shooping?no

# %%
# add Create a place to store purchased items 🛒 cart, cart.append() -add one new item at the end of the list
cart = []

cart.append(["apple", 2, 60])

cart.append(["banana", 3, 30])

print(cart)
# Out:
# [['apple', 2, 60], ['banana', 3, 30]]

# %%
product={"apple":30,"banana":10,"milk":20,"yogurt":15}
cart=[]
while True:
    choice=input("enter the product:").lower()
    quantity=int(input("enter the quantity:"))
    if choice in product:
        print("product is available")
        print("price:",product[choice])
        total=product[choice]*quantity
        print("total:",total)
        cart.append([choice,quantity,total])
        print(cart)
    else:
        print("sorry!product is not available")
    again=input("do you want to continue shooping?").lower()
    if again=='no':
       break
# Out:
# enter the product:apple
# enter the quantity:5
# product is available
# price: 30
# total: 150
# [['apple', 5, 150]]
# do you want to continue shooping?no

# %%
product={"apple":30,"banana":10,"milk":20,"yogurt":15}
cart=[]
while True:
    choice=input("enter the product:").lower()
    quantity=int(input("enter the quantity:"))
    if choice in product:
        print("product is available")
        print("price:",product[choice])
        total=product[choice]*quantity
        print("total:",total)
        cart.append([choice,quantity,total])
        print(cart)
    else:
        print("sorry!product is not available")
    again=input("do you want to continue shooping?").lower()
    if again=='no':
       break
print("------Finalbill----------")
grand_total=0
for items in cart:
    print(items[0],items[1],items[2])
    grand_total=grand_total+items[2]
print("total amount:",grand_total)
# Out:
# enter the product:apple
# enter the quantity:10
# product is available
# price: 30
# total: 300
# [['apple', 10, 300]]
# do you want to continue shooping?yes
# enter the product:orange
# enter the quantity:2
# sorry!product is not available
# do you want to continue shooping?yes
# enter the product:milk
# enter the quantity:2
# product is available
# price: 20
# total: 40
# [['apple', 10, 300], ['milk', 2, 40]]
# do you want to continue shooping?no
# ------Finalbill----------
# apple 10 300
# milk 2 40
# total amount: 340
